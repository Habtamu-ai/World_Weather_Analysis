# %% [markdown]
# ## Deliverable 3. Create a Travel Itinerary Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

# Import API key
from config import g_key

# Configure gmaps
gmaps.configure(api_key=g_key)

# %%
# 1. Read the WeatherPy_vacation.csv into a DataFrame.
vacation_df = pd.read_csv("WeatherPy_vacation.csv")
vacation_df
# Out:
#      City_ID            City Country  Max Temp Current Description    Lat  \
# 0          1       Moustheni      GR     16.11          few clouds  40.87
# 1          5  Ribeira Grande      PT     16.00       broken clouds  38.52
# 2          6         Rikitea      PF     24.28     overcast clouds -23.12
# 3          7        Hermanus      ZA     23.33     overcast clouds -34.42
# 4          9     Broken Hill      AU     22.00           clear sky -31.95
# ..       ...             ...     ...       ...                 ...    ...
# 260      671         Kamenka      RU     14.44          few clouds  51.32
# 261      673          Cobija      BO     24.00    scattered clouds -11.03
# 262      679         Peniche      PT     17.78           clear sky  39.36
# 263      680            Tala      EG     22.59    scattered clouds  30.68
# 264      682         Sirnach      CH     18.00       broken clouds  47.46
#
#         Lng                  Hotel Name
# ...

# %%
# 2. Using the template add the city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Weather Description</dt><dd>{Current Description}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °C</dd>
</dl>
"""

# 3a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in vacation_df.iterrows()]

# 3b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = vacation_df[["Lat", "Lng"]]

# %%
# 4a. Add a marker layer for each city to the map.

locations = vacation_df[["Lat", "Lng"]]
max_temp = vacation_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,dissipating=False,
             max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)


# 4b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
vacation_df =  vacation_df[vacation_df["Country"] == "BR"]
vacation_df
# Out:
#      City_ID                      City Country  Max Temp Current Description  \
# 15        29                    Castro      BR     15.62     overcast clouds
# 23        46         Sao Joao Da Barra      BR     24.00           clear sky
# 33        61                  Cananeia      BR     22.89    scattered clouds
# 43        86           Arraial Do Cabo      BR     25.00          few clouds
# 62       142                   Vilhena      BR     21.00           clear sky
# 97       250  Sao Gabriel Da Cachoeira      BR     23.68     overcast clouds
# 101      271                     Pilar      BR     25.00       broken clouds
# 109      290              Itamarandiba      BR     22.79          few clouds
# 124      329                Vila Velha      BR     24.00           clear sky
# 125      332                  Cidreira      BR     21.12    scattered clouds
# 153      406                 Bataipora      BR     21.68       broken clouds
# ...

# %%
vacation_df.reset_index(drop=True,inplace=True)
vacation_df
# Out:
#     City_ID                      City Country  Max Temp Current Description  \
# 0        29                    Castro      BR     15.62     overcast clouds
# 1        46         Sao Joao Da Barra      BR     24.00           clear sky
# 2        61                  Cananeia      BR     22.89    scattered clouds
# 3        86           Arraial Do Cabo      BR     25.00          few clouds
# 4       142                   Vilhena      BR     21.00           clear sky
# 5       250  Sao Gabriel Da Cachoeira      BR     23.68     overcast clouds
# 6       271                     Pilar      BR     25.00       broken clouds
# 7       290              Itamarandiba      BR     22.79          few clouds
# 8       329                Vila Velha      BR     24.00           clear sky
# 9       332                  Cidreira      BR     21.12    scattered clouds
# 10      406                 Bataipora      BR     21.68       broken clouds
# ...

# %%
9,10,11,12
# Out:
# (9, 10, 11, 12)

# %%
# From the map above pick 4 cities 
#and create a vacation itinerary route to travel between the four cities. 
# 5. Create DataFrames for each city by filtering the 'vacation_df' using the loc method. 
# Hint: The starting and ending city should be the same city.

vacation_start = vacation_df.loc[9]["Lat"],vacation_df.loc[9]["Lng"]
vacation_end = vacation_df.loc[9]["Lat"],vacation_df.loc[9]["Lng"]
vacation_stop1 = vacation_df.loc[10]["Lat"],vacation_df.loc[10]["Lng"]
vacation_stop2 = vacation_df.loc[11]["Lat"],vacation_df.loc[11]["Lng"]
vacation_stop3 = vacation_df.loc[12]["Lat"],vacation_df.loc[12]["Lng"]

# %%
vacationitenary_df = vacation_df[(vacation_df["City"] == "Cidreira") | 
                                 (vacation_df["City"] == "Bataipora") | 
                                 (vacation_df["City"] == "Imbituba") | 
                                 (vacation_df["City"] == "Ribeirao Branco")]  
# selectedItenary_df.append(my_itenary.loc[4:6])
vacationitenary_df
# Out:
#     City_ID             City Country  Max Temp Current Description    Lat  \
# 9       332         Cidreira      BR     21.12    scattered clouds -30.18
# 10      406        Bataipora      BR     21.68       broken clouds -22.30
# 11      429         Imbituba      BR     21.00           clear sky -28.24
# 12      558  Ribeirao Branco      BR     17.83       broken clouds -24.22
#
#       Lng                    Hotel Name
# 9  -50.21                 Hotel Castelo
# 10 -53.27        Hotel Vale do Ivinhema
# 11 -48.67          Praia Hotel Imbituba
# 12 -48.77  Restaurante Hotel Andorinhas

# %%
# 6. Get the latitude-longitude pairs as tuples from each city DataFrame using the to_numpy function and list indexing.
start =vacation_start
end =vacation_end
stop1 =vacation_stop1
stop2 = vacation_stop2
stop3 = vacation_stop3

# %%
# 7. Create a direction layer map using the start and end latitude-longitude pairs,
# and stop1, stop2, and stop3 as the waypoints. The travel_mode should be "DRIVING", "BICYCLING", or "WALKING".
import gmaps.datasets
gmaps.configure(api_key=g_key)

fig = gmaps.figure()

start_to_end = gmaps.directions_layer(vacation_start,vacation_end, waypoints=
[vacation_stop1, vacation_stop2,vacation_stop3],
travel_mode='DRIVING')

fig.add_layer(start_to_end)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# 8. To create a marker layer map between the four cities.
#  Combine the four city DataFrames into one DataFrame using the concat() function.
itinerary_df = pd.concat([],ignore_index=True)
itinerary_df

# %%
# 9 Using the template add city name, the country code, the weather description and maximum temperature for the city. 
info_box_template = """

"""

# 10a Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in itinerary_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = itinerary_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map.

# 11b. Display the figure
