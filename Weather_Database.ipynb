# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
from config import weather_api_key

# %%
#3. Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
#4.Get the nearest city using the citipy module.
cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 737

# %%
#5.Perform an API call with the OpenWeatherMap.
url = "http://api.openweathermap.org/data/2.5/weather?units=metric&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=metric&APPID=3048952140c217a651e6568a04441f08

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" +"Alexandria"
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=metric&APPID=3048952140c217a651e6568a04441f08&q=Alexandria

# %%
# Make a 'Get' request for the city weather.
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
# Retrieve the following information from the API call:
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
      
       
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})
                       

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | port keats
# Processing Record 2 of Set 1 | bredasdorp
# Processing Record 3 of Set 1 | barrow
# Processing Record 4 of Set 1 | vancouver
# Processing Record 5 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 6 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 7 of Set 1 | arraial do cabo
# Processing Record 8 of Set 1 | san cristobal
# Processing Record 9 of Set 1 | thompson
# Processing Record 10 of Set 1 | alghero
# Processing Record 11 of Set 1 | mataura
# Processing Record 12 of Set 1 | new norfolk
# Processing Record 13 of Set 1 | tasiilaq
# Processing Record 14 of Set 1 | jalna
# Processing Record 15 of Set 1 | castro
# Processing Record 16 of Set 1 | jamestown
# Processing Record 17 of Set 1 | kinango
# Processing Record 18 of Set 1 | hokitika
# Processing Record 19 of Set 1 | busselton
# Processing Record 20 of Set 1 | san patricio
# Processing Record 21 of Set 1 | beyneu
# Processing Record 22 of Set 1 | vrangel
# Processing Record 23 of Set 1 | puerto ayora
# Processing Record 24 of Set 1 | punta arenas
# Processing Record 25 of Set 1 | ushuaia
# Processing Record 26 of Set 1 | nouadhibou
# Processing Record 27 of Set 1 | padang
# Processing Record 28 of Set 1 | port elizabeth
# Processing Record 29 of Set 1 | saskylakh
# Processing Record 30 of Set 1 | alice springs
# Processing Record 31 of Set 1 | crixas
# Processing Record 32 of Set 1 | albany
# Processing Record 33 of Set 1 | bathsheba
# Processing Record 34 of Set 1 | alberton
# Processing Record 35 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 36 of Set 1 | rikitea
# Processing Record 37 of Set 1 | krasnoselkup
# Processing Record 38 of Set 1 | punta de piedra
# Processing Record 39 of Set 1 | bethel
# Processing Record 40 of Set 1 | ancud
# Processing Record 41 of Set 1 | san andres
# Processing Record 42 of Set 1 | erzin
# Processing Record 43 of Set 1 | dharchula
# Processing Record 44 of Set 1 | hobart
# Processing Record 45 of Set 1 | saint-philippe
# Processing Record 46 of Set 1 | henties bay
# Processing Record 47 of Set 1 | fort beaufort
# Processing Record 48 of Set 1 | saint george
# Processing Record 49 of Set 1 | amuntai
# Processing Record 50 of Set 1 | yellowknife
# Processing Record 1 of Set 2 | maumere
# Processing Record 2 of Set 2 | khatanga
# Processing Record 3 of Set 2 | zaraysk
# Processing Record 4 of Set 2 | bluff
# Processing Record 5 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 6 of Set 2 | leningradskiy
# Processing Record 7 of Set 2 | tuatapere
# Processing Record 8 of Set 2 | bengkulu
# Processing Record 9 of Set 2 | newcastle
# Processing Record 10 of Set 2 | chuy
# Processing Record 11 of Set 2 | qaanaaq
# Processing Record 12 of Set 2 | ovsyanka
# Processing Record 13 of Set 2 | road town
# Processing Record 14 of Set 2 | mildura
# Processing Record 15 of Set 2 | kailua
# Processing Record 16 of Set 2 | lively
# Processing Record 17 of Set 2 | mount gambier
# Processing Record 18 of Set 2 | cabo san lucas
# Processing Record 19 of Set 2 | mahebourg
# Processing Record 20 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 21 of Set 2 | tuktoyaktuk
# Processing Record 22 of Set 2 | namagiripettai
# Processing Record 23 of Set 2 | atuona
# Processing Record 24 of Set 2 | khromtau
# Processing Record 25 of Set 2 | eldorado
# Processing Record 26 of Set 2 | taoudenni
# Processing Record 27 of Set 2 | longyearbyen
# Processing Record 28 of Set 2 | esperance
# Processing Record 29 of Set 2 | dikson
# Processing Record 30 of Set 2 | pangody
# Processing Record 31 of Set 2 | amapa
# Processing Record 32 of Set 2 | aranos
# Processing Record 33 of Set 2 | lagoa
# Processing Record 34 of Set 2 | omboue
# Processing Record 35 of Set 2 | yulara
# Processing Record 36 of Set 2 | faanui
# Processing Record 37 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 38 of Set 2 | georgetown
# Processing Record 39 of Set 2 | jalu
# Processing Record 40 of Set 2 | severo-kurilsk
# Processing Record 41 of Set 2 | ocozocoautla
# City not found. Skipping...
# Processing Record 42 of Set 2 | gladstone
# Processing Record 43 of Set 2 | cidreira
# Processing Record 44 of Set 2 | naze
# Processing Record 45 of Set 2 | chokurdakh
# Processing Record 46 of Set 2 | gamba
# Processing Record 47 of Set 2 | college
# Processing Record 48 of Set 2 | victoria
# Processing Record 49 of Set 2 | kapaa
# Processing Record 50 of Set 2 | margate
# Processing Record 1 of Set 3 | cayenne
# Processing Record 2 of Set 3 | ambulu
# Processing Record 3 of Set 3 | paamiut
# Processing Record 4 of Set 3 | ishigaki
# Processing Record 5 of Set 3 | narsaq
# Processing Record 6 of Set 3 | samarkand
# Processing Record 7 of Set 3 | aflu
# City not found. Skipping...
# Processing Record 8 of Set 3 | hobyo
# Processing Record 9 of Set 3 | iquitos
# Processing Record 10 of Set 3 | umea
# Processing Record 11 of Set 3 | wanning
# Processing Record 12 of Set 3 | itamaraju
# Processing Record 13 of Set 3 | mancio lima
# Processing Record 14 of Set 3 | hermanus
# Processing Record 15 of Set 3 | hilo
# Processing Record 16 of Set 3 | port lincoln
# Processing Record 17 of Set 3 | chapais
# Processing Record 18 of Set 3 | mbulu
# Processing Record 19 of Set 3 | irbeyskoye
# Processing Record 20 of Set 3 | belogorsk
# Processing Record 21 of Set 3 | colares
# Processing Record 22 of Set 3 | elko
# Processing Record 23 of Set 3 | goderich
# Processing Record 24 of Set 3 | katsuura
# Processing Record 25 of Set 3 | labuan
# Processing Record 26 of Set 3 | coihaique
# Processing Record 27 of Set 3 | san clemente
# Processing Record 28 of Set 3 | upernavik
# Processing Record 29 of Set 3 | srednekolymsk
# Processing Record 30 of Set 3 | shingu
# Processing Record 31 of Set 3 | likasi
# Processing Record 32 of Set 3 | kendari
# Processing Record 33 of Set 3 | kaitangata
# Processing Record 34 of Set 3 | namibe
# Processing Record 35 of Set 3 | tabuk
# Processing Record 36 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 37 of Set 3 | yumen
# Processing Record 38 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 39 of Set 3 | lebu
# Processing Record 40 of Set 3 | fortuna
# Processing Record 41 of Set 3 | caiaponia
# Processing Record 42 of Set 3 | sao miguel do araguaia
# Processing Record 43 of Set 3 | vaini
# Processing Record 44 of Set 3 | nikolskoye
# Processing Record 45 of Set 3 | butembo
# Processing Record 46 of Set 3 | doha
# Processing Record 47 of Set 3 | axim
# Processing Record 48 of Set 3 | sao jose da coroa grande
# Processing Record 49 of Set 3 | pisco
# Processing Record 50 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 1 of Set 4 | whitehorse
# Processing Record 2 of Set 4 | avarua
# Processing Record 3 of Set 4 | launceston
# Processing Record 4 of Set 4 | butaritari
# Processing Record 5 of Set 4 | boundiali
# Processing Record 6 of Set 4 | khandbari
# Processing Record 7 of Set 4 | aanekoski
# Processing Record 8 of Set 4 | ulladulla
# Processing Record 9 of Set 4 | sao filipe
# Processing Record 10 of Set 4 | ocampo
# Processing Record 11 of Set 4 | constitucion
# Processing Record 12 of Set 4 | talcahuano
# Processing Record 13 of Set 4 | riyadh
# Processing Record 14 of Set 4 | guarapari
# Processing Record 15 of Set 4 | faya
# Processing Record 16 of Set 4 | buariki
# City not found. Skipping...
# Processing Record 17 of Set 4 | kodiak
# Processing Record 18 of Set 4 | okha
# Processing Record 19 of Set 4 | havelock
# Processing Record 20 of Set 4 | dapaong
# Processing Record 21 of Set 4 | pitimbu
# Processing Record 22 of Set 4 | port alfred
# Processing Record 23 of Set 4 | ponta do sol
# Processing Record 24 of Set 4 | muravlenko
# Processing Record 25 of Set 4 | poya
# Processing Record 26 of Set 4 | bambous virieux
# Processing Record 27 of Set 4 | svetlogorsk
# Processing Record 28 of Set 4 | bindura
# Processing Record 29 of Set 4 | hihifo
# City not found. Skipping...
# Processing Record 30 of Set 4 | mingguang
# Processing Record 31 of Set 4 | tutoia
# Processing Record 32 of Set 4 | qaqortoq
# Processing Record 33 of Set 4 | vila velha
# Processing Record 34 of Set 4 | byron bay
# Processing Record 35 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 36 of Set 4 | east london
# Processing Record 37 of Set 4 | mbeya
# Processing Record 38 of Set 4 | zyryanka
# Processing Record 39 of Set 4 | port hardy
# Processing Record 40 of Set 4 | waipawa
# Processing Record 41 of Set 4 | marang
# Processing Record 42 of Set 4 | smithers
# Processing Record 43 of Set 4 | purranque
# Processing Record 44 of Set 4 | labrea
# Processing Record 45 of Set 4 | baykit
# Processing Record 46 of Set 4 | mar del plata
# Processing Record 47 of Set 4 | port-gentil
# Processing Record 48 of Set 4 | katobu
# Processing Record 49 of Set 4 | ratnagiri
# Processing Record 50 of Set 4 | sibolga
# Processing Record 1 of Set 5 | marsh harbour
# Processing Record 2 of Set 5 | pingliang
# Processing Record 3 of Set 5 | ponta delgada
# Processing Record 4 of Set 5 | san quintin
# Processing Record 5 of Set 5 | marathon
# Processing Record 6 of Set 5 | vila franca do campo
# Processing Record 7 of Set 5 | kruisfontein
# Processing Record 8 of Set 5 | thaba nchu
# Processing Record 9 of Set 5 | bubaque
# Processing Record 10 of Set 5 | mayumba
# Processing Record 11 of Set 5 | codrington
# Processing Record 12 of Set 5 | jega
# Processing Record 13 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 14 of Set 5 | talnakh
# Processing Record 15 of Set 5 | ubon ratchathani
# Processing Record 16 of Set 5 | russell
# Processing Record 17 of Set 5 | rosario do sul
# Processing Record 18 of Set 5 | llata
# Processing Record 19 of Set 5 | torbay
# Processing Record 20 of Set 5 | kitami
# Processing Record 21 of Set 5 | dzhebariki-khaya
# Processing Record 22 of Set 5 | tidore
# City not found. Skipping...
# Processing Record 23 of Set 5 | ebnat-kappel
# Processing Record 24 of Set 5 | norman wells
# Processing Record 25 of Set 5 | hithadhoo
# Processing Record 26 of Set 5 | wagar
# Processing Record 27 of Set 5 | nishihara
# Processing Record 28 of Set 5 | loubomo
# Processing Record 29 of Set 5 | peto
# Processing Record 30 of Set 5 | rio grande
# Processing Record 31 of Set 5 | ambilobe
# Processing Record 32 of Set 5 | hambantota
# Processing Record 33 of Set 5 | kindia
# Processing Record 34 of Set 5 | srivardhan
# Processing Record 35 of Set 5 | fereydun kenar
# Processing Record 36 of Set 5 | ilhabela
# Processing Record 37 of Set 5 | yuxia
# Processing Record 38 of Set 5 | souillac
# Processing Record 39 of Set 5 | gariaband
# Processing Record 40 of Set 5 | sao joao da barra
# Processing Record 41 of Set 5 | paragominas
# Processing Record 42 of Set 5 | tongliao
# Processing Record 43 of Set 5 | along
# Processing Record 44 of Set 5 | beringovskiy
# Processing Record 45 of Set 5 | husavik
# Processing Record 46 of Set 5 | nanortalik
# Processing Record 47 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 48 of Set 5 | bandarbeyla
# Processing Record 49 of Set 5 | la ronge
# Processing Record 50 of Set 5 | nhulunbuy
# Processing Record 1 of Set 6 | cape town
# Processing Record 2 of Set 6 | fort saint john
# City not found. Skipping...
# Processing Record 3 of Set 6 | hailey
# Processing Record 4 of Set 6 | porto santo
# Processing Record 5 of Set 6 | ambo
# Processing Record 6 of Set 6 | cerqueira cesar
# Processing Record 7 of Set 6 | skibbereen
# Processing Record 8 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 9 of Set 6 | hasaki
# Processing Record 10 of Set 6 | kahului
# Processing Record 11 of Set 6 | boa vista
# Processing Record 12 of Set 6 | marawi
# Processing Record 13 of Set 6 | tecoanapa
# Processing Record 14 of Set 6 | sola
# Processing Record 15 of Set 6 | los algarrobos
# Processing Record 16 of Set 6 | mantua
# Processing Record 17 of Set 6 | tougan
# Processing Record 18 of Set 6 | hofn
# Processing Record 19 of Set 6 | nome
# Processing Record 20 of Set 6 | vanderhoof
# Processing Record 21 of Set 6 | bima
# Processing Record 22 of Set 6 | valparaiso
# Processing Record 23 of Set 6 | salalah
# Processing Record 24 of Set 6 | mobara
# Processing Record 25 of Set 6 | nisia floresta
# Processing Record 26 of Set 6 | ossora
# Processing Record 27 of Set 6 | andenes
# Processing Record 28 of Set 6 | vila
# Processing Record 29 of Set 6 | deputatskiy
# Processing Record 30 of Set 6 | nizhniy ingash
# Processing Record 31 of Set 6 | aginskoye
# Processing Record 32 of Set 6 | guerrero negro
# Processing Record 33 of Set 6 | thunder bay
# Processing Record 34 of Set 6 | dingle
# Processing Record 35 of Set 6 | nong khai
# Processing Record 36 of Set 6 | cherskiy
# Processing Record 37 of Set 6 | chara
# Processing Record 38 of Set 6 | ribeira grande
# Processing Record 39 of Set 6 | ustka
# Processing Record 40 of Set 6 | monte carmelo
# Processing Record 41 of Set 6 | nanzhang
# Processing Record 42 of Set 6 | cockburn town
# Processing Record 43 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 44 of Set 6 | sabang
# Processing Record 45 of Set 6 | muros
# Processing Record 46 of Set 6 | hualmay
# Processing Record 47 of Set 6 | besancon
# Processing Record 48 of Set 6 | kamenka
# Processing Record 49 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 50 of Set 6 | necochea
# Processing Record 1 of Set 7 | contamana
# Processing Record 2 of Set 7 | seminole
# Processing Record 3 of Set 7 | luderitz
# Processing Record 4 of Set 7 | abu samrah
# Processing Record 5 of Set 7 | lompoc
# Processing Record 6 of Set 7 | carnarvon
# Processing Record 7 of Set 7 | flinders
# Processing Record 8 of Set 7 | marsa matruh
# Processing Record 9 of Set 7 | lucapa
# Processing Record 10 of Set 7 | broome
# Processing Record 11 of Set 7 | vaxjo
# Processing Record 12 of Set 7 | north bend
# Processing Record 13 of Set 7 | alpena
# Processing Record 14 of Set 7 | vanavara
# Processing Record 15 of Set 7 | dolbeau
# City not found. Skipping...
# Processing Record 16 of Set 7 | egvekinot
# Processing Record 17 of Set 7 | khovu-aksy
# Processing Record 18 of Set 7 | rovaniemi
# Processing Record 19 of Set 7 | pevek
# Processing Record 20 of Set 7 | tocopilla
# Processing Record 21 of Set 7 | poum
# Processing Record 22 of Set 7 | vao
# Processing Record 23 of Set 7 | tarko-sale
# Processing Record 24 of Set 7 | lichinga
# Processing Record 25 of Set 7 | oberwart
# Processing Record 26 of Set 7 | baglan
# Processing Record 27 of Set 7 | buzmeyin
# Processing Record 28 of Set 7 | barra do garcas
# Processing Record 29 of Set 7 | kem
# Processing Record 30 of Set 7 | burns lake
# Processing Record 31 of Set 7 | lorengau
# Processing Record 32 of Set 7 | darhan
# Processing Record 33 of Set 7 | laguna
# Processing Record 34 of Set 7 | suileng
# Processing Record 35 of Set 7 | tiksi
# Processing Record 36 of Set 7 | barra da estiva
# Processing Record 37 of Set 7 | imuris
# Processing Record 38 of Set 7 | iqaluit
# Processing Record 39 of Set 7 | corn island
# Processing Record 40 of Set 7 | harindanga
# Processing Record 41 of Set 7 | vestmannaeyjar
# Processing Record 42 of Set 7 | hamilton
# Processing Record 43 of Set 7 | bitung
# Processing Record 44 of Set 7 | varhaug
# Processing Record 45 of Set 7 | vercheres
# Processing Record 46 of Set 7 | nortelandia
# Processing Record 47 of Set 7 | tortosa
# Processing Record 48 of Set 7 | jumla
# Processing Record 49 of Set 7 | kropotkin
# Processing Record 50 of Set 7 | bonthe
# Processing Record 1 of Set 8 | atar
# Processing Record 2 of Set 8 | kharan
# Processing Record 3 of Set 8 | solovetskiy
# City not found. Skipping...
# Processing Record 4 of Set 8 | cibitoke
# Processing Record 5 of Set 8 | yar-sale
# Processing Record 6 of Set 8 | thinadhoo
# Processing Record 7 of Set 8 | eucaliptus
# Processing Record 8 of Set 8 | poli
# Processing Record 9 of Set 8 | lumby
# Processing Record 10 of Set 8 | mpika
# Processing Record 11 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 12 of Set 8 | airai
# Processing Record 13 of Set 8 | kushima
# Processing Record 14 of Set 8 | provideniya
# Processing Record 15 of Set 8 | togur
# Processing Record 16 of Set 8 | clyde river
# Processing Record 17 of Set 8 | beisfjord
# Processing Record 18 of Set 8 | cabadiangan
# Processing Record 19 of Set 8 | menongue
# Processing Record 20 of Set 8 | the valley
# Processing Record 21 of Set 8 | kirensk
# Processing Record 22 of Set 8 | vangaindrano
# Processing Record 23 of Set 8 | zinder
# Processing Record 24 of Set 8 | makokou
# Processing Record 25 of Set 8 | sao felix do xingu
# Processing Record 26 of Set 8 | pandaria
# Processing Record 27 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 28 of Set 8 | batavia
# Processing Record 29 of Set 8 | khor
# Processing Record 30 of Set 8 | katangli
# Processing Record 31 of Set 8 | otane
# Processing Record 32 of Set 8 | chabahar
# Processing Record 33 of Set 8 | los llanos de aridane
# Processing Record 34 of Set 8 | santa rosalia
# Processing Record 35 of Set 8 | tumut
# Processing Record 36 of Set 8 | arlit
# Processing Record 37 of Set 8 | navoloki
# Processing Record 38 of Set 8 | pinawa
# Processing Record 39 of Set 8 | lac du bonnet
# Processing Record 40 of Set 8 | old saybrook
# Processing Record 41 of Set 8 | koygorodok
# Processing Record 42 of Set 8 | ixtapa
# Processing Record 43 of Set 8 | qena
# Processing Record 44 of Set 8 | lasa
# Processing Record 45 of Set 8 | brae
# Processing Record 46 of Set 8 | rawson
# Processing Record 47 of Set 8 | jacareacanga
# Processing Record 48 of Set 8 | kutum
# Processing Record 49 of Set 8 | payson
# Processing Record 50 of Set 8 | kibara
# Processing Record 1 of Set 9 | nueva concepcion
# Processing Record 2 of Set 9 | tucuma
# Processing Record 3 of Set 9 | aklavik
# Processing Record 4 of Set 9 | saint anthony
# Processing Record 5 of Set 9 | galiwinku
# City not found. Skipping...
# Processing Record 6 of Set 9 | kalabo
# Processing Record 7 of Set 9 | ulagan
# Processing Record 8 of Set 9 | tautira
# Processing Record 9 of Set 9 | bizhbulyak
# Processing Record 10 of Set 9 | atagay
# Processing Record 11 of Set 9 | hilton head island
# Processing Record 12 of Set 9 | kieta
# Processing Record 13 of Set 9 | pacasmayo
# Processing Record 14 of Set 9 | manta
# Processing Record 15 of Set 9 | san jose
# Processing Record 16 of Set 9 | zeya
# Processing Record 17 of Set 9 | bundaberg
# Processing Record 18 of Set 9 | camopi
# Processing Record 19 of Set 9 | sadat
# Processing Record 20 of Set 9 | banjar
# Processing Record 21 of Set 9 | lakatoro
# Processing Record 22 of Set 9 | zabol
# Processing Record 23 of Set 9 | price
# Processing Record 24 of Set 9 | kerrville
# Processing Record 25 of Set 9 | rafai
# Processing Record 26 of Set 9 | moerai
# Processing Record 27 of Set 9 | karoi
# Processing Record 28 of Set 9 | merauke
# Processing Record 29 of Set 9 | olbia
# Processing Record 30 of Set 9 | caravelas
# Processing Record 31 of Set 9 | conceicao das alagoas
# Processing Record 32 of Set 9 | mogochin
# City not found. Skipping...
# Processing Record 33 of Set 9 | kavieng
# Processing Record 34 of Set 9 | rong kwang
# Processing Record 35 of Set 9 | kudahuvadhoo
# Processing Record 36 of Set 9 | noumea
# Processing Record 37 of Set 9 | dingzhou
# Processing Record 38 of Set 9 | mezen
# Processing Record 39 of Set 9 | high rock
# Processing Record 40 of Set 9 | longlac
# City not found. Skipping...
# Processing Record 41 of Set 9 | saint-pierre
# Processing Record 42 of Set 9 | burica
# City not found. Skipping...
# Processing Record 43 of Set 9 | babanusah
# City not found. Skipping...
# Processing Record 44 of Set 9 | sena madureira
# Processing Record 45 of Set 9 | delta del tigre
# Processing Record 46 of Set 9 | teguldet
# Processing Record 47 of Set 9 | grand gaube
# Processing Record 48 of Set 9 | lavrentiya
# Processing Record 49 of Set 9 | uige
# Processing Record 50 of Set 9 | kanadey
# Processing Record 1 of Set 10 | saint-joseph
# Processing Record 2 of Set 10 | sitka
# Processing Record 3 of Set 10 | dunedin
# Processing Record 4 of Set 10 | auki
# Processing Record 5 of Set 10 | mitsamiouli
# Processing Record 6 of Set 10 | vestmanna
# Processing Record 7 of Set 10 | klaksvik
# Processing Record 8 of Set 10 | ambon
# Processing Record 9 of Set 10 | acarau
# Processing Record 10 of Set 10 | alzamay
# Processing Record 11 of Set 10 | ilulissat
# Processing Record 12 of Set 10 | ghanzi
# Processing Record 13 of Set 10 | zhangye
# Processing Record 14 of Set 10 | coruripe
# Processing Record 15 of Set 10 | carauari
# Processing Record 16 of Set 10 | sechura
# Processing Record 17 of Set 10 | uyemskiy
# Processing Record 18 of Set 10 | rognan
# Processing Record 19 of Set 10 | bardiyah
# Processing Record 20 of Set 10 | waddan
# Processing Record 21 of Set 10 | coquimbo
# Processing Record 22 of Set 10 | pangnirtung
# Processing Record 23 of Set 10 | adrar
# Processing Record 24 of Set 10 | san mariano
# Processing Record 25 of Set 10 | basoko
# Processing Record 26 of Set 10 | saldanha
# Processing Record 27 of Set 10 | moses lake
# Processing Record 28 of Set 10 | dali
# Processing Record 29 of Set 10 | fukue
# Processing Record 30 of Set 10 | plettenberg bay
# Processing Record 31 of Set 10 | sambava
# Processing Record 32 of Set 10 | zvishavane
# Processing Record 33 of Set 10 | barawe
# City not found. Skipping...
# Processing Record 34 of Set 10 | buala
# Processing Record 35 of Set 10 | sorland
# Processing Record 36 of Set 10 | tshikapa
# Processing Record 37 of Set 10 | samarai
# Processing Record 38 of Set 10 | anahuac
# Processing Record 39 of Set 10 | kyaikto
# Processing Record 40 of Set 10 | aykhal
# Processing Record 41 of Set 10 | praia
# Processing Record 42 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 43 of Set 10 | catacocha
# Processing Record 44 of Set 10 | borogontsy
# Processing Record 45 of Set 10 | sobolevo
# Processing Record 46 of Set 10 | lata
# Processing Record 47 of Set 10 | alofi
# Processing Record 48 of Set 10 | wamba
# Processing Record 49 of Set 10 | edson
# Processing Record 50 of Set 10 | thiers
# Processing Record 1 of Set 11 | kozhva
# Processing Record 2 of Set 11 | najran
# Processing Record 3 of Set 11 | nicoya
# Processing Record 4 of Set 11 | neepawa
# Processing Record 5 of Set 11 | orsta
# Processing Record 6 of Set 11 | ayan
# Processing Record 7 of Set 11 | kalianget
# Processing Record 8 of Set 11 | celestun
# Processing Record 9 of Set 11 | zouxian
# City not found. Skipping...
# Processing Record 10 of Set 11 | buin
# Processing Record 11 of Set 11 | ballina
# Processing Record 12 of Set 11 | kavaratti
# Processing Record 13 of Set 11 | itarema
# Processing Record 14 of Set 11 | asau
# Processing Record 15 of Set 11 | baruun-urt
# Processing Record 16 of Set 11 | quartucciu
# Processing Record 17 of Set 11 | nemuro
# Processing Record 18 of Set 11 | sumbe
# Processing Record 19 of Set 11 | pacifica
# Processing Record 20 of Set 11 | mamallapuram
# Processing Record 21 of Set 11 | saint-augustin
# Processing Record 22 of Set 11 | minas
# Processing Record 23 of Set 11 | antofagasta
# Processing Record 24 of Set 11 | tijara
# Processing Record 25 of Set 11 | atbasar
# Processing Record 26 of Set 11 | nuuk
# Processing Record 27 of Set 11 | lesnoy
# Processing Record 28 of Set 11 | huilong
# Processing Record 29 of Set 11 | kedrovyy
# Processing Record 30 of Set 11 | praia da vitoria
# Processing Record 31 of Set 11 | kapit
# Processing Record 32 of Set 11 | komsomolskiy
# Processing Record 33 of Set 11 | duz
# City not found. Skipping...
# Processing Record 34 of Set 11 | tukrah
# Processing Record 35 of Set 11 | fayaoue
# Processing Record 36 of Set 11 | porosozero
# Processing Record 37 of Set 11 | kirakira
# Processing Record 38 of Set 11 | yeniseysk
# Processing Record 39 of Set 11 | juneau
# Processing Record 40 of Set 11 | turukhansk
# Processing Record 41 of Set 11 | ostrovnoy
# Processing Record 42 of Set 11 | santiago
# Processing Record 43 of Set 11 | santa fe
# Processing Record 44 of Set 11 | homer
# Processing Record 45 of Set 11 | samalaeulu
# City not found. Skipping...
# Processing Record 46 of Set 11 | saint-georges
# Processing Record 47 of Set 11 | dalvik
# Processing Record 48 of Set 11 | luanda
# Processing Record 49 of Set 11 | preobrazheniye
# Processing Record 50 of Set 11 | shaowu
# Processing Record 1 of Set 12 | bonavista
# Processing Record 2 of Set 12 | acapulco
# Processing Record 3 of Set 12 | aalen
# Processing Record 4 of Set 12 | kang
# Processing Record 5 of Set 12 | gyonk
# Processing Record 6 of Set 12 | krasnyy chikoy
# Processing Record 7 of Set 12 | sur
# Processing Record 8 of Set 12 | hauterive
# Processing Record 9 of Set 12 | belmonte
# Processing Record 10 of Set 12 | havre-saint-pierre
# Processing Record 11 of Set 12 | palana
# Processing Record 12 of Set 12 | rudnya
# Processing Record 13 of Set 12 | gigmoto
# Processing Record 14 of Set 12 | kemijarvi
# Processing Record 15 of Set 12 | kalmunai
# Processing Record 16 of Set 12 | portland
# Processing Record 17 of Set 12 | liuhe
# Processing Record 18 of Set 12 | princeton
# Processing Record 19 of Set 12 | karpathos
# Processing Record 20 of Set 12 | tieli
# Processing Record 21 of Set 12 | ramgarh
# Processing Record 22 of Set 12 | port augusta
# Processing Record 23 of Set 12 | meadow lake
# Processing Record 24 of Set 12 | union
# Processing Record 25 of Set 12 | ternate
# Processing Record 26 of Set 12 | tomatlan
# Processing Record 27 of Set 12 | vallenar
# Processing Record 28 of Set 12 | villanueva de la serena
# Processing Record 29 of Set 12 | mechetinskaya
# Processing Record 30 of Set 12 | san carlos de bariloche
# Processing Record 31 of Set 12 | port macquarie
# Processing Record 32 of Set 12 | lewisporte
# Processing Record 33 of Set 12 | pahrump
# Processing Record 34 of Set 12 | anadyr
# Processing Record 35 of Set 12 | smolenka
# Processing Record 36 of Set 12 | morgan city
# Processing Record 37 of Set 12 | richards bay
# Processing Record 38 of Set 12 | leshukonskoye
# Processing Record 39 of Set 12 | barroualie
# City not found. Skipping...
# Processing Record 40 of Set 12 | tura
# Processing Record 41 of Set 12 | alencon
# Processing Record 42 of Set 12 | santiago de cao
# Processing Record 43 of Set 12 | we
# City not found. Skipping...
# Processing Record 44 of Set 12 | bowen
# Processing Record 45 of Set 12 | okhotsk
# Processing Record 46 of Set 12 | banes
# Processing Record 47 of Set 12 | maragogi
# Processing Record 48 of Set 12 | phalodi
# Processing Record 49 of Set 12 | wahiawa
# Processing Record 50 of Set 12 | tygda
# Processing Record 1 of Set 13 | keetmanshoop
# Processing Record 2 of Set 13 | qui nhon
# Processing Record 3 of Set 13 | cuprija
# Processing Record 4 of Set 13 | gamboma
# Processing Record 5 of Set 13 | mehamn
# Processing Record 6 of Set 13 | mount pleasant
# Processing Record 7 of Set 13 | missoula
# Processing Record 8 of Set 13 | shakawe
# Processing Record 9 of Set 13 | jalandhar
# Processing Record 10 of Set 13 | virginia beach
# Processing Record 11 of Set 13 | grande-riviere
# City not found. Skipping...
# Processing Record 12 of Set 13 | farah
# Processing Record 13 of Set 13 | khandyga
# Processing Record 14 of Set 13 | merritt island
# Processing Record 15 of Set 13 | viransehir
# Processing Record 16 of Set 13 | isangel
# Processing Record 17 of Set 13 | salvador
# Processing Record 18 of Set 13 | puro
# Processing Record 19 of Set 13 | lagos
# Processing Record 20 of Set 13 | sura
# Processing Record 21 of Set 13 | montevideo
# Processing Record 22 of Set 13 | lakes entrance
# Processing Record 23 of Set 13 | nyurba
# Processing Record 24 of Set 13 | phuket
# Processing Record 25 of Set 13 | kizema
# Processing Record 26 of Set 13 | te anau
# Processing Record 27 of Set 13 | parana
# Processing Record 28 of Set 13 | landskrona
# Processing Record 29 of Set 13 | ngukurr
# City not found. Skipping...
# Processing Record 30 of Set 13 | karaul
# City not found. Skipping...
# Processing Record 31 of Set 13 | touros
# Processing Record 32 of Set 13 | valls
# Processing Record 33 of Set 13 | killybegs
# Processing Record 34 of Set 13 | namatanai
# Processing Record 35 of Set 13 | salinas
# Processing Record 36 of Set 13 | vuktyl
# Processing Record 37 of Set 13 | huntsville
# Processing Record 38 of Set 13 | umm lajj
# Processing Record 39 of Set 13 | tarakan
# Processing Record 40 of Set 13 | lundazi
# Processing Record 41 of Set 13 | guilin
# Processing Record 42 of Set 13 | vardo
# Processing Record 43 of Set 13 | geraldton
# Processing Record 44 of Set 13 | lopukhiv
# Processing Record 45 of Set 13 | savelugu
# Processing Record 46 of Set 13 | biak
# Processing Record 47 of Set 13 | pankovka
# Processing Record 48 of Set 13 | aden
# Processing Record 49 of Set 13 | fandriana
# Processing Record 50 of Set 13 | pauini
# Processing Record 1 of Set 14 | stornoway
# Processing Record 2 of Set 14 | fairbanks
# Processing Record 3 of Set 14 | ust-tsilma
# Processing Record 4 of Set 14 | yudong
# Processing Record 5 of Set 14 | makakilo city
# Processing Record 6 of Set 14 | prainha
# Processing Record 7 of Set 14 | yichun
# Processing Record 8 of Set 14 | nampula
# Processing Record 9 of Set 14 | medvezhyegorsk
# Processing Record 10 of Set 14 | havoysund
# Processing Record 11 of Set 14 | berlevag
# Processing Record 12 of Set 14 | mananara
# Processing Record 13 of Set 14 | yeppoon
# Processing Record 14 of Set 14 | puerto escondido
# Processing Record 15 of Set 14 | half moon bay
# Processing Record 16 of Set 14 | dunayivtsi
# City not found. Skipping...
# Processing Record 17 of Set 14 | marcona
# City not found. Skipping...
# Processing Record 18 of Set 14 | maple creek
# Processing Record 19 of Set 14 | tamiahua
# Processing Record 20 of Set 14 | vostok
# Processing Record 21 of Set 14 | baherden
# Processing Record 22 of Set 14 | barra patuca
# Processing Record 23 of Set 14 | bar harbor
# Processing Record 24 of Set 14 | obluche
# City not found. Skipping...
# Processing Record 25 of Set 14 | oktyabrskoye
# Processing Record 26 of Set 14 | natal
# Processing Record 27 of Set 14 | krasnozerskoye
# Processing Record 28 of Set 14 | cravo norte
# Processing Record 29 of Set 14 | chuzhou
# Processing Record 30 of Set 14 | vieques
# Processing Record 31 of Set 14 | umm durman
# City not found. Skipping...
# Processing Record 32 of Set 14 | labuhan
# Processing Record 33 of Set 14 | amahai
# Processing Record 34 of Set 14 | poronaysk
# Processing Record 35 of Set 14 | yaan
# Processing Record 36 of Set 14 | beloha
# Processing Record 37 of Set 14 | ushtobe
# Processing Record 38 of Set 14 | domoni
# Processing Record 39 of Set 14 | mahajanga
# Processing Record 40 of Set 14 | ust-kulom
# Processing Record 41 of Set 14 | nedjo
# Processing Record 42 of Set 14 | chaochou
# City not found. Skipping...
# Processing Record 43 of Set 14 | methoni
# Processing Record 44 of Set 14 | ahipara
# Processing Record 45 of Set 14 | udachnyy
# Processing Record 46 of Set 14 | buraydah
# Processing Record 47 of Set 14 | quatre cocos
# Processing Record 48 of Set 14 | haljala
# Processing Record 49 of Set 14 | griffith
# Processing Record 50 of Set 14 | mariental
# Processing Record 1 of Set 15 | baza
# Processing Record 2 of Set 15 | wad rawah
# Processing Record 3 of Set 15 | oussouye
# Processing Record 4 of Set 15 | inhambane
# Processing Record 5 of Set 15 | walvis bay
# Processing Record 6 of Set 15 | batagay-alyta
# Processing Record 7 of Set 15 | hanna
# Processing Record 8 of Set 15 | port blair
# Processing Record 9 of Set 15 | louisbourg
# City not found. Skipping...
# Processing Record 10 of Set 15 | jarjis
# City not found. Skipping...
# Processing Record 11 of Set 15 | sidhi
# Processing Record 12 of Set 15 | xinpu
# Processing Record 13 of Set 15 | port hedland
# Processing Record 14 of Set 15 | camacha
# Processing Record 15 of Set 15 | tazovskiy
# Processing Record 16 of Set 15 | mananjary
# Processing Record 17 of Set 15 | miraflores
# Processing Record 18 of Set 15 | lerwick
# Processing Record 19 of Set 15 | flin flon
# Processing Record 20 of Set 15 | gat
# Processing Record 21 of Set 15 | abu zabad
# Processing Record 22 of Set 15 | saryshagan
# City not found. Skipping...
# Processing Record 23 of Set 15 | luena
# Processing Record 24 of Set 15 | zalantun
# Processing Record 25 of Set 15 | bagotville
# Processing Record 26 of Set 15 | bud
# Processing Record 27 of Set 15 | billings
# Processing Record 28 of Set 15 | ahvaz
# Processing Record 29 of Set 15 | shaunavon
# Processing Record 30 of Set 15 | alta floresta
# Processing Record 31 of Set 15 | yei
# Processing Record 32 of Set 15 | witu
# Processing Record 33 of Set 15 | christchurch
# Processing Record 34 of Set 15 | tilichiki
# Processing Record 35 of Set 15 | sol-iletsk
# Processing Record 36 of Set 15 | huancavelica
# Processing Record 37 of Set 15 | bustamante
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df
len(city_data)
# Out:
# 690

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)

# Reorder the column order
new_column_order = ["City", "Country", "Lat","Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

city_data_df = city_data_df[new_column_order]

city_data_df
# Out:
#                 City Country      Lat       Lng  Max Temp  Humidity  \
# 0         Port Keats      AU -14.2500  129.5500     27.04        81
# 1         Bredasdorp      ZA -34.5322   20.0403     16.00        72
# 2             Barrow      US  71.2906 -156.7887    -24.00        84
# 3          Vancouver      CA  49.2497 -123.1193     10.56        66
# 4    Arraial Do Cabo      BR -22.9661  -42.0278     26.00        78
# ..               ...     ...      ...       ...       ...       ...
# 685     Christchurch      NZ -43.5333  172.6333     22.22        46
# 686        Tilichiki      RU  60.4667  166.1000    -17.11        88
# 687       Sol-Iletsk      RU  51.1631   54.9918     -3.09        97
# 688     Huancavelica      PE -12.7667  -74.9833      4.84        86
# 689       Bustamante      MX  26.5333 -100.5000     32.48        13
#
#      Cloudiness  Wind Speed Current Description
# 0           100        2.71     overcast clouds
# 1             2        3.09           clear sky
# 2            20        1.54          few clouds
# 3            75        2.57       broken clouds
# 4            20        4.63          few clouds
# ..          ...         ...                 ...
# 685          67        3.60       broken clouds
# 686          25        2.58    scattered clouds
# 687         100        3.20                snow
# 688          75        2.16       moderate rain
# 689           2        5.10           clear sky
#
# [690 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the weather_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
