# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
from config import weather_api_key

# %%
#3. Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
#4.Get the nearest city using the citipy module.
cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 742

# %%
#5.Perform an API call with the OpenWeatherMap.
url = "http://api.openweathermap.org/data/2.5/weather?units=metric&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=metric&APPID=3048952140c217a651e6568a04441f08

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" +"Alexandria"
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=metric&APPID=3048952140c217a651e6568a04441f08&q=Alexandria

# %%
# Make a 'Get' request for the city weather.
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
# Retrieve the following information from the API call:
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
      
       
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})
                       

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | punta arenas
# Processing Record 2 of Set 1 | moustheni
# Processing Record 3 of Set 1 | ushuaia
# Processing Record 4 of Set 1 | fayaoue
# Processing Record 5 of Set 1 | albany
# Processing Record 6 of Set 1 | ribeira grande
# Processing Record 7 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 8 of Set 1 | rikitea
# Processing Record 9 of Set 1 | hermanus
# Processing Record 10 of Set 1 | lagdo
# Processing Record 11 of Set 1 | broken hill
# Processing Record 12 of Set 1 | new norfolk
# Processing Record 13 of Set 1 | nishihara
# Processing Record 14 of Set 1 | butaritari
# Processing Record 15 of Set 1 | kahului
# Processing Record 16 of Set 1 | itoman
# Processing Record 17 of Set 1 | jamestown
# Processing Record 18 of Set 1 | carnarvon
# Processing Record 19 of Set 1 | komsomolskiy
# Processing Record 20 of Set 1 | yumen
# Processing Record 21 of Set 1 | hobart
# Processing Record 22 of Set 1 | busselton
# Processing Record 23 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 24 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 25 of Set 1 | spencer
# Processing Record 26 of Set 1 | kalmunai
# Processing Record 27 of Set 1 | bluff
# Processing Record 28 of Set 1 | huilong
# Processing Record 29 of Set 1 | owando
# Processing Record 30 of Set 1 | codrington
# Processing Record 31 of Set 1 | olafsvik
# Processing Record 32 of Set 1 | kozhva
# Processing Record 33 of Set 1 | castro
# Processing Record 34 of Set 1 | torbay
# Processing Record 35 of Set 1 | murray bridge
# Processing Record 36 of Set 1 | barrow
# Processing Record 37 of Set 1 | carahue
# Processing Record 38 of Set 1 | avarua
# Processing Record 39 of Set 1 | basco
# Processing Record 40 of Set 1 | atuona
# Processing Record 41 of Set 1 | mar del plata
# Processing Record 42 of Set 1 | hegang
# Processing Record 43 of Set 1 | husavik
# Processing Record 44 of Set 1 | yellowknife
# Processing Record 45 of Set 1 | nuuk
# Processing Record 46 of Set 1 | iquique
# Processing Record 47 of Set 1 | tocopilla
# Processing Record 48 of Set 1 | norman wells
# Processing Record 49 of Set 1 | villa carlos paz
# Processing Record 50 of Set 1 | sao joao da barra
# Processing Record 1 of Set 2 | gunnedah
# Processing Record 2 of Set 2 | erenhot
# Processing Record 3 of Set 2 | vaini
# Processing Record 4 of Set 2 | thompson
# Processing Record 5 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 6 of Set 2 | lompoc
# Processing Record 7 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 8 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 9 of Set 2 | ishigaki
# Processing Record 10 of Set 2 | chernyshevskiy
# Processing Record 11 of Set 2 | kazalinsk
# City not found. Skipping...
# Processing Record 12 of Set 2 | remontnoye
# Processing Record 13 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 14 of Set 2 | chililabombwe
# Processing Record 15 of Set 2 | kuminskiy
# Processing Record 16 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 17 of Set 2 | dicabisagan
# Processing Record 18 of Set 2 | lakatoro
# Processing Record 19 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 20 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 21 of Set 2 | puerto madryn
# Processing Record 22 of Set 2 | dunedin
# Processing Record 23 of Set 2 | cananeia
# Processing Record 24 of Set 2 | chuy
# Processing Record 25 of Set 2 | cape town
# Processing Record 26 of Set 2 | lingao
# Processing Record 27 of Set 2 | kapaa
# Processing Record 28 of Set 2 | harper
# Processing Record 29 of Set 2 | sukumo
# Processing Record 30 of Set 2 | hasaki
# Processing Record 31 of Set 2 | cacu
# Processing Record 32 of Set 2 | bogalusa
# Processing Record 33 of Set 2 | batagay
# Processing Record 34 of Set 2 | mount gambier
# Processing Record 35 of Set 2 | palmer
# Processing Record 36 of Set 2 | bokspits
# City not found. Skipping...
# Processing Record 37 of Set 2 | provideniya
# Processing Record 38 of Set 2 | port alfred
# Processing Record 39 of Set 2 | cockburn town
# Processing Record 40 of Set 2 | longyearbyen
# Processing Record 41 of Set 2 | aklavik
# Processing Record 42 of Set 2 | roald
# Processing Record 43 of Set 2 | mataura
# Processing Record 44 of Set 2 | omboue
# Processing Record 45 of Set 2 | vorobyevka
# Processing Record 46 of Set 2 | carlsbad
# Processing Record 47 of Set 2 | berezovka
# Processing Record 48 of Set 2 | khatanga
# Processing Record 49 of Set 2 | arraial do cabo
# Processing Record 50 of Set 2 | itacare
# Processing Record 1 of Set 3 | tuktoyaktuk
# Processing Record 2 of Set 3 | georgetown
# Processing Record 3 of Set 3 | gat
# Processing Record 4 of Set 3 | kaohsiung
# Processing Record 5 of Set 3 | cabedelo
# Processing Record 6 of Set 3 | roma
# Processing Record 7 of Set 3 | epiniana
# Processing Record 8 of Set 3 | akonolinga
# Processing Record 9 of Set 3 | clyde river
# Processing Record 10 of Set 3 | puerto escondido
# Processing Record 11 of Set 3 | poum
# Processing Record 12 of Set 3 | upernavik
# Processing Record 13 of Set 3 | guerrero negro
# Processing Record 14 of Set 3 | airai
# Processing Record 15 of Set 3 | kruisfontein
# Processing Record 16 of Set 3 | heiligenhafen
# Processing Record 17 of Set 3 | hamburg
# Processing Record 18 of Set 3 | sitka
# Processing Record 19 of Set 3 | anadyr
# Processing Record 20 of Set 3 | victoria
# Processing Record 21 of Set 3 | dabakala
# Processing Record 22 of Set 3 | moron
# Processing Record 23 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 24 of Set 3 | santa cruz
# Processing Record 25 of Set 3 | qaanaaq
# Processing Record 26 of Set 3 | san carlos de bariloche
# Processing Record 27 of Set 3 | tual
# Processing Record 28 of Set 3 | lebu
# Processing Record 29 of Set 3 | araouane
# Processing Record 30 of Set 3 | jiuquan
# Processing Record 31 of Set 3 | carndonagh
# Processing Record 32 of Set 3 | sikonge
# Processing Record 33 of Set 3 | abhar
# Processing Record 34 of Set 3 | touros
# Processing Record 35 of Set 3 | grindavik
# Processing Record 36 of Set 3 | nikolayevka
# Processing Record 37 of Set 3 | hay river
# Processing Record 38 of Set 3 | faanui
# Processing Record 39 of Set 3 | saint-pierre
# Processing Record 40 of Set 3 | marawi
# Processing Record 41 of Set 3 | kharp
# Processing Record 42 of Set 3 | bredasdorp
# Processing Record 43 of Set 3 | upata
# Processing Record 44 of Set 3 | luanda
# Processing Record 45 of Set 3 | mayor pablo lagerenza
# Processing Record 46 of Set 3 | champerico
# Processing Record 47 of Set 3 | vila
# Processing Record 48 of Set 3 | half moon bay
# Processing Record 49 of Set 3 | belaya gora
# Processing Record 50 of Set 3 | vanimo
# Processing Record 1 of Set 4 | kodiak
# Processing Record 2 of Set 4 | puerto carreno
# Processing Record 3 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 4 of Set 4 | jabinyanah
# Processing Record 5 of Set 4 | biloela
# Processing Record 6 of Set 4 | chokurdakh
# Processing Record 7 of Set 4 | vilhena
# Processing Record 8 of Set 4 | sayansk
# Processing Record 9 of Set 4 | tura
# Processing Record 10 of Set 4 | westport
# Processing Record 11 of Set 4 | saint-philippe
# Processing Record 12 of Set 4 | homer
# Processing Record 13 of Set 4 | sirisia
# City not found. Skipping...
# Processing Record 14 of Set 4 | ituni
# City not found. Skipping...
# Processing Record 15 of Set 4 | topeka
# Processing Record 16 of Set 4 | stokmarknes
# Processing Record 17 of Set 4 | east london
# Processing Record 18 of Set 4 | tasiilaq
# Processing Record 19 of Set 4 | louisbourg
# City not found. Skipping...
# Processing Record 20 of Set 4 | benguela
# Processing Record 21 of Set 4 | saskylakh
# Processing Record 22 of Set 4 | tiznit
# Processing Record 23 of Set 4 | talcahuano
# Processing Record 24 of Set 4 | mantua
# Processing Record 25 of Set 4 | feuchtwangen
# Processing Record 26 of Set 4 | umm lajj
# Processing Record 27 of Set 4 | pizarro
# Processing Record 28 of Set 4 | gamba
# Processing Record 29 of Set 4 | pevek
# Processing Record 30 of Set 4 | faya
# Processing Record 31 of Set 4 | kununurra
# Processing Record 32 of Set 4 | hithadhoo
# Processing Record 33 of Set 4 | te anau
# Processing Record 34 of Set 4 | vilyuysk
# Processing Record 35 of Set 4 | vryburg
# Processing Record 36 of Set 4 | avera
# Processing Record 37 of Set 4 | coihaique
# Processing Record 38 of Set 4 | shumskiy
# Processing Record 39 of Set 4 | nakambala
# Processing Record 40 of Set 4 | yulara
# Processing Record 41 of Set 4 | port elizabeth
# Processing Record 42 of Set 4 | nikolskoye
# Processing Record 43 of Set 4 | hilo
# Processing Record 44 of Set 4 | saint george
# Processing Record 45 of Set 4 | bambous virieux
# Processing Record 46 of Set 4 | agar
# Processing Record 47 of Set 4 | corner brook
# Processing Record 48 of Set 4 | mount isa
# Processing Record 49 of Set 4 | gisborne
# Processing Record 50 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 1 of Set 5 | oudtshoorn
# Processing Record 2 of Set 5 | geraldton
# Processing Record 3 of Set 5 | sung noen
# Processing Record 4 of Set 5 | tessalit
# Processing Record 5 of Set 5 | linhares
# Processing Record 6 of Set 5 | fortuna
# Processing Record 7 of Set 5 | adwa
# Processing Record 8 of Set 5 | namibe
# Processing Record 9 of Set 5 | vardo
# Processing Record 10 of Set 5 | almaznyy
# Processing Record 11 of Set 5 | khonuu
# City not found. Skipping...
# Processing Record 12 of Set 5 | matheran
# Processing Record 13 of Set 5 | taoudenni
# Processing Record 14 of Set 5 | gogapur
# Processing Record 15 of Set 5 | ilulissat
# Processing Record 16 of Set 5 | nome
# Processing Record 17 of Set 5 | namatanai
# Processing Record 18 of Set 5 | san policarpo
# Processing Record 19 of Set 5 | akureyri
# Processing Record 20 of Set 5 | terrace
# Processing Record 21 of Set 5 | puerto ayora
# Processing Record 22 of Set 5 | catia la mar
# Processing Record 23 of Set 5 | hami
# Processing Record 24 of Set 5 | kudahuvadhoo
# Processing Record 25 of Set 5 | sovetskiy
# Processing Record 26 of Set 5 | buraydah
# Processing Record 27 of Set 5 | caranavi
# Processing Record 28 of Set 5 | shaoguan
# Processing Record 29 of Set 5 | laguna
# Processing Record 30 of Set 5 | hokitika
# Processing Record 31 of Set 5 | qandahar
# City not found. Skipping...
# Processing Record 32 of Set 5 | kosh-agach
# Processing Record 33 of Set 5 | bontang
# Processing Record 34 of Set 5 | mahebourg
# Processing Record 35 of Set 5 | san quintin
# Processing Record 36 of Set 5 | katsuura
# Processing Record 37 of Set 5 | pisco
# Processing Record 38 of Set 5 | tuatapere
# Processing Record 39 of Set 5 | walvis bay
# Processing Record 40 of Set 5 | coahuayana
# Processing Record 41 of Set 5 | diego de almagro
# Processing Record 42 of Set 5 | bengkulu
# Processing Record 43 of Set 5 | chalus
# Processing Record 44 of Set 5 | cherskiy
# Processing Record 45 of Set 5 | srednekolymsk
# Processing Record 46 of Set 5 | berezovyy
# Processing Record 47 of Set 5 | la palma
# Processing Record 48 of Set 5 | turukhansk
# Processing Record 49 of Set 5 | izumo
# Processing Record 50 of Set 5 | tautira
# Processing Record 1 of Set 6 | montepuez
# Processing Record 2 of Set 6 | portland
# Processing Record 3 of Set 6 | bilibino
# Processing Record 4 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 5 of Set 6 | kadyy
# Processing Record 6 of Set 6 | bang saphan
# Processing Record 7 of Set 6 | pucallpa
# Processing Record 8 of Set 6 | inderborskiy
# City not found. Skipping...
# Processing Record 9 of Set 6 | lagoa
# Processing Record 10 of Set 6 | ponta do sol
# Processing Record 11 of Set 6 | eha amufu
# Processing Record 12 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 13 of Set 6 | gorin
# Processing Record 14 of Set 6 | ust-ilimsk
# Processing Record 15 of Set 6 | waingapu
# Processing Record 16 of Set 6 | moose factory
# Processing Record 17 of Set 6 | katobu
# Processing Record 18 of Set 6 | tabas
# Processing Record 19 of Set 6 | naze
# Processing Record 20 of Set 6 | robertsport
# Processing Record 21 of Set 6 | kaitangata
# Processing Record 22 of Set 6 | lorengau
# Processing Record 23 of Set 6 | constitucion
# Processing Record 24 of Set 6 | sao gabriel da cachoeira
# Processing Record 25 of Set 6 | kattivakkam
# Processing Record 26 of Set 6 | scarborough
# Processing Record 27 of Set 6 | imeni poliny osipenko
# Processing Record 28 of Set 6 | bangui
# Processing Record 29 of Set 6 | itarema
# Processing Record 30 of Set 6 | skibbereen
# Processing Record 31 of Set 6 | houston
# Processing Record 32 of Set 6 | goundam
# Processing Record 33 of Set 6 | the valley
# Processing Record 34 of Set 6 | dhidhdhoo
# Processing Record 35 of Set 6 | matara
# Processing Record 36 of Set 6 | mareeba
# Processing Record 37 of Set 6 | baghmara
# Processing Record 38 of Set 6 | souillac
# Processing Record 39 of Set 6 | narsaq
# Processing Record 40 of Set 6 | dingle
# Processing Record 41 of Set 6 | jumla
# Processing Record 42 of Set 6 | chubbuck
# Processing Record 43 of Set 6 | narodychi
# Processing Record 44 of Set 6 | klaksvik
# Processing Record 45 of Set 6 | pilar
# Processing Record 46 of Set 6 | kracheh
# City not found. Skipping...
# Processing Record 47 of Set 6 | sabha
# Processing Record 48 of Set 6 | buala
# Processing Record 49 of Set 6 | severo-kurilsk
# Processing Record 50 of Set 6 | akdepe
# Processing Record 1 of Set 7 | batsfjord
# Processing Record 2 of Set 7 | simpang
# Processing Record 3 of Set 7 | mpongwe
# Processing Record 4 of Set 7 | terney
# Processing Record 5 of Set 7 | paka
# Processing Record 6 of Set 7 | banmankhi
# Processing Record 7 of Set 7 | pachino
# Processing Record 8 of Set 7 | puerto cabello
# Processing Record 9 of Set 7 | larreynaga
# Processing Record 10 of Set 7 | galesong
# Processing Record 11 of Set 7 | nicolas bravo
# Processing Record 12 of Set 7 | tevriz
# Processing Record 13 of Set 7 | ewa beach
# Processing Record 14 of Set 7 | shingu
# Processing Record 15 of Set 7 | itamarandiba
# Processing Record 16 of Set 7 | bud
# Processing Record 17 of Set 7 | san cristobal
# Processing Record 18 of Set 7 | hamilton
# Processing Record 19 of Set 7 | caravelas
# Processing Record 20 of Set 7 | hillsborough
# Processing Record 21 of Set 7 | quelimane
# Processing Record 22 of Set 7 | tzucacab
# Processing Record 23 of Set 7 | strai
# Processing Record 24 of Set 7 | channel-port aux basques
# Processing Record 25 of Set 7 | camacha
# Processing Record 26 of Set 7 | usinsk
# Processing Record 27 of Set 7 | tra vinh
# Processing Record 28 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 29 of Set 7 | narasannapeta
# Processing Record 30 of Set 7 | tateyama
# Processing Record 31 of Set 7 | general roca
# Processing Record 32 of Set 7 | salalah
# Processing Record 33 of Set 7 | khorixas
# Processing Record 34 of Set 7 | pangnirtung
# Processing Record 35 of Set 7 | saint-louis
# Processing Record 36 of Set 7 | san rafael
# Processing Record 37 of Set 7 | northam
# Processing Record 38 of Set 7 | aban
# Processing Record 39 of Set 7 | sendhwa
# Processing Record 40 of Set 7 | samoded
# Processing Record 41 of Set 7 | xining
# Processing Record 42 of Set 7 | vieux-habitants
# Processing Record 43 of Set 7 | tiarei
# Processing Record 44 of Set 7 | shimanovsk
# Processing Record 45 of Set 7 | san vicente
# Processing Record 46 of Set 7 | bethel
# Processing Record 47 of Set 7 | comodoro rivadavia
# Processing Record 48 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 49 of Set 7 | teknaf
# Processing Record 50 of Set 7 | college
# Processing Record 1 of Set 8 | kanchanaburi
# Processing Record 2 of Set 8 | egvekinot
# Processing Record 3 of Set 8 | santona
# Processing Record 4 of Set 8 | okha
# Processing Record 5 of Set 8 | nevers
# Processing Record 6 of Set 8 | vila velha
# Processing Record 7 of Set 8 | kenora
# Processing Record 8 of Set 8 | banda aceh
# Processing Record 9 of Set 8 | cidreira
# Processing Record 10 of Set 8 | hambantota
# Processing Record 11 of Set 8 | ambodifototra
# City not found. Skipping...
# Processing Record 12 of Set 8 | talnakh
# Processing Record 13 of Set 8 | vydrino
# Processing Record 14 of Set 8 | arlit
# Processing Record 15 of Set 8 | gilgit
# Processing Record 16 of Set 8 | kindu
# Processing Record 17 of Set 8 | agadir
# Processing Record 18 of Set 8 | turbat
# Processing Record 19 of Set 8 | sibolga
# Processing Record 20 of Set 8 | takayama
# Processing Record 21 of Set 8 | hualmay
# Processing Record 22 of Set 8 | santiago del estero
# Processing Record 23 of Set 8 | clarence town
# Processing Record 24 of Set 8 | pacific grove
# Processing Record 25 of Set 8 | luderitz
# Processing Record 26 of Set 8 | turnu rosu
# Processing Record 27 of Set 8 | kem
# Processing Record 28 of Set 8 | nantucket
# Processing Record 29 of Set 8 | luwuk
# Processing Record 30 of Set 8 | hirara
# Processing Record 31 of Set 8 | nong han
# Processing Record 32 of Set 8 | isiro
# Processing Record 33 of Set 8 | alofi
# Processing Record 34 of Set 8 | plettenberg bay
# Processing Record 35 of Set 8 | lagos
# Processing Record 36 of Set 8 | sungaipenuh
# Processing Record 37 of Set 8 | tidore
# City not found. Skipping...
# Processing Record 38 of Set 8 | waipawa
# Processing Record 39 of Set 8 | sampit
# Processing Record 40 of Set 8 | zaysan
# Processing Record 41 of Set 8 | ancud
# Processing Record 42 of Set 8 | chambishi
# Processing Record 43 of Set 8 | palembang
# Processing Record 44 of Set 8 | saint anthony
# Processing Record 45 of Set 8 | san angelo
# Processing Record 46 of Set 8 | den helder
# Processing Record 47 of Set 8 | kangaatsiaq
# Processing Record 48 of Set 8 | mirnyy
# Processing Record 49 of Set 8 | waddan
# Processing Record 50 of Set 8 | abu kamal
# Processing Record 1 of Set 9 | kutum
# Processing Record 2 of Set 9 | port hawkesbury
# Processing Record 3 of Set 9 | kirillov
# Processing Record 4 of Set 9 | presidencia roque saenz pena
# Processing Record 5 of Set 9 | luganville
# Processing Record 6 of Set 9 | boyabat
# Processing Record 7 of Set 9 | burnie
# Processing Record 8 of Set 9 | tulagi
# Processing Record 9 of Set 9 | cumberland
# Processing Record 10 of Set 9 | soyo
# Processing Record 11 of Set 9 | muros
# Processing Record 12 of Set 9 | payo
# Processing Record 13 of Set 9 | sisimiut
# Processing Record 14 of Set 9 | cabo san lucas
# Processing Record 15 of Set 9 | nemuro
# Processing Record 16 of Set 9 | hornepayne
# Processing Record 17 of Set 9 | beringovskiy
# Processing Record 18 of Set 9 | neiafu
# Processing Record 19 of Set 9 | tungkang
# City not found. Skipping...
# Processing Record 20 of Set 9 | tocache
# Processing Record 21 of Set 9 | achisay
# City not found. Skipping...
# Processing Record 22 of Set 9 | khash
# Processing Record 23 of Set 9 | port lincoln
# Processing Record 24 of Set 9 | tiksi
# Processing Record 25 of Set 9 | phan thiet
# Processing Record 26 of Set 9 | rovaniemi
# Processing Record 27 of Set 9 | stepnyak
# Processing Record 28 of Set 9 | semporna
# Processing Record 29 of Set 9 | wamba
# Processing Record 30 of Set 9 | dossor
# Processing Record 31 of Set 9 | hailun
# Processing Record 32 of Set 9 | thinadhoo
# Processing Record 33 of Set 9 | panguna
# Processing Record 34 of Set 9 | great yarmouth
# Processing Record 35 of Set 9 | mahuva
# Processing Record 36 of Set 9 | berdsk
# Processing Record 37 of Set 9 | bataipora
# Processing Record 38 of Set 9 | unity
# Processing Record 39 of Set 9 | catamarca
# Processing Record 40 of Set 9 | sakakah
# Processing Record 41 of Set 9 | hihifo
# City not found. Skipping...
# Processing Record 42 of Set 9 | juneau
# Processing Record 43 of Set 9 | sarakhs
# Processing Record 44 of Set 9 | saint-augustin
# Processing Record 45 of Set 9 | inskoy
# Processing Record 46 of Set 9 | bosaso
# Processing Record 47 of Set 9 | sidi ali
# Processing Record 48 of Set 9 | timmins
# Processing Record 49 of Set 9 | nanortalik
# Processing Record 50 of Set 9 | benjamin aceval
# Processing Record 1 of Set 10 | tuy hoa
# Processing Record 2 of Set 10 | zhezkazgan
# Processing Record 3 of Set 10 | yirol
# City not found. Skipping...
# Processing Record 4 of Set 10 | killybegs
# Processing Record 5 of Set 10 | bria
# Processing Record 6 of Set 10 | auki
# Processing Record 7 of Set 10 | ahipara
# Processing Record 8 of Set 10 | kemijarvi
# Processing Record 9 of Set 10 | ostrovnoy
# Processing Record 10 of Set 10 | abu samrah
# Processing Record 11 of Set 10 | vestmannaeyjar
# Processing Record 12 of Set 10 | imbituba
# Processing Record 13 of Set 10 | sinnamary
# Processing Record 14 of Set 10 | sangar
# Processing Record 15 of Set 10 | saint-georges
# Processing Record 16 of Set 10 | collie
# Processing Record 17 of Set 10 | cayenne
# Processing Record 18 of Set 10 | bealanana
# Processing Record 19 of Set 10 | sinjah
# City not found. Skipping...
# Processing Record 20 of Set 10 | sundby
# Processing Record 21 of Set 10 | makakilo city
# Processing Record 22 of Set 10 | porto recanati
# Processing Record 23 of Set 10 | bardiyah
# Processing Record 24 of Set 10 | baraki barak
# Processing Record 25 of Set 10 | barranca
# Processing Record 26 of Set 10 | auray
# Processing Record 27 of Set 10 | fukue
# Processing Record 28 of Set 10 | dustlik
# Processing Record 29 of Set 10 | lavrentiya
# Processing Record 30 of Set 10 | sembakung
# Processing Record 31 of Set 10 | marsh harbour
# Processing Record 32 of Set 10 | muroto
# Processing Record 33 of Set 10 | san ignacio
# Processing Record 34 of Set 10 | havoysund
# Processing Record 35 of Set 10 | bandiagara
# Processing Record 36 of Set 10 | dikson
# Processing Record 37 of Set 10 | hachinohe
# Processing Record 38 of Set 10 | dayong
# Processing Record 39 of Set 10 | chuzhou
# Processing Record 40 of Set 10 | ruhengeri
# Processing Record 41 of Set 10 | salinas
# Processing Record 42 of Set 10 | samarai
# Processing Record 43 of Set 10 | nago
# Processing Record 44 of Set 10 | hofn
# Processing Record 45 of Set 10 | cintalapa
# Processing Record 46 of Set 10 | bubaque
# Processing Record 47 of Set 10 | lasa
# Processing Record 48 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 49 of Set 10 | skalistyy
# City not found. Skipping...
# Processing Record 50 of Set 10 | san andres
# Processing Record 1 of Set 11 | haines junction
# Processing Record 2 of Set 11 | ossora
# Processing Record 3 of Set 11 | duluth
# Processing Record 4 of Set 11 | kotovo
# Processing Record 5 of Set 11 | esperance
# Processing Record 6 of Set 11 | susangerd
# Processing Record 7 of Set 11 | lubumbashi
# Processing Record 8 of Set 11 | buin
# Processing Record 9 of Set 11 | padang
# Processing Record 10 of Set 11 | bahir dar
# Processing Record 11 of Set 11 | miri
# Processing Record 12 of Set 11 | aguadilla
# Processing Record 13 of Set 11 | sao filipe
# Processing Record 14 of Set 11 | derzhavinsk
# Processing Record 15 of Set 11 | deputatskiy
# Processing Record 16 of Set 11 | inhambane
# Processing Record 17 of Set 11 | emba
# Processing Record 18 of Set 11 | ongandjera
# Processing Record 19 of Set 11 | chumikan
# Processing Record 20 of Set 11 | nanakuli
# Processing Record 21 of Set 11 | vallenar
# Processing Record 22 of Set 11 | igarka
# Processing Record 23 of Set 11 | huarmey
# Processing Record 24 of Set 11 | esil
# Processing Record 25 of Set 11 | arman
# Processing Record 26 of Set 11 | xinzhi
# Processing Record 27 of Set 11 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 28 of Set 11 | niono
# Processing Record 29 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 30 of Set 11 | cairns
# Processing Record 31 of Set 11 | isangel
# Processing Record 32 of Set 11 | sola
# Processing Record 33 of Set 11 | malabo
# Processing Record 34 of Set 11 | phichit
# Processing Record 35 of Set 11 | yichang
# Processing Record 36 of Set 11 | mabaruma
# Processing Record 37 of Set 11 | okhotsk
# Processing Record 38 of Set 11 | laslea
# Processing Record 39 of Set 11 | alice springs
# Processing Record 40 of Set 11 | millet
# Processing Record 41 of Set 11 | marsabit
# Processing Record 42 of Set 11 | nador
# Processing Record 43 of Set 11 | yoichi
# Processing Record 44 of Set 11 | kuchera
# Processing Record 45 of Set 11 | bobonong
# City not found. Skipping...
# Processing Record 46 of Set 11 | inirida
# Processing Record 47 of Set 11 | seydi
# Processing Record 48 of Set 11 | karratha
# Processing Record 49 of Set 11 | uchiza
# Processing Record 50 of Set 11 | phan rang
# City not found. Skipping...
# Processing Record 1 of Set 12 | ayna
# Processing Record 2 of Set 12 | kasongo
# Processing Record 3 of Set 12 | katherine
# Processing Record 4 of Set 12 | pecos
# Processing Record 5 of Set 12 | zhigansk
# Processing Record 6 of Set 12 | utiroa
# City not found. Skipping...
# Processing Record 7 of Set 12 | shimoda
# Processing Record 8 of Set 12 | lakes entrance
# Processing Record 9 of Set 12 | christchurch
# Processing Record 10 of Set 12 | brae
# Processing Record 11 of Set 12 | vila do maio
# Processing Record 12 of Set 12 | road town
# Processing Record 13 of Set 12 | fairbanks
# Processing Record 14 of Set 12 | ivdel
# Processing Record 15 of Set 12 | lima
# Processing Record 16 of Set 12 | hobyo
# Processing Record 17 of Set 12 | saleaula
# City not found. Skipping...
# Processing Record 18 of Set 12 | simav
# Processing Record 19 of Set 12 | windsor
# Processing Record 20 of Set 12 | rosarito
# Processing Record 21 of Set 12 | corn island
# Processing Record 22 of Set 12 | kampene
# Processing Record 23 of Set 12 | miles city
# Processing Record 24 of Set 12 | los llanos de aridane
# Processing Record 25 of Set 12 | ngunguru
# Processing Record 26 of Set 12 | oistins
# Processing Record 27 of Set 12 | tianpeng
# Processing Record 28 of Set 12 | vao
# Processing Record 29 of Set 12 | carbonia
# Processing Record 30 of Set 12 | wulanhaote
# City not found. Skipping...
# Processing Record 31 of Set 12 | mocambique
# City not found. Skipping...
# Processing Record 32 of Set 12 | snihurivka
# Processing Record 33 of Set 12 | graham
# Processing Record 34 of Set 12 | maragogi
# Processing Record 35 of Set 12 | rawson
# Processing Record 36 of Set 12 | witu
# Processing Record 37 of Set 12 | conde
# Processing Record 38 of Set 12 | saldanha
# Processing Record 39 of Set 12 | dunda
# Processing Record 40 of Set 12 | eruwa
# Processing Record 41 of Set 12 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 42 of Set 12 | rokytne
# Processing Record 43 of Set 12 | khani
# Processing Record 44 of Set 12 | chushan
# Processing Record 45 of Set 12 | ruzomberok
# Processing Record 46 of Set 12 | mezen
# Processing Record 47 of Set 12 | babanusah
# City not found. Skipping...
# Processing Record 48 of Set 12 | batagay-alyta
# Processing Record 49 of Set 12 | filadelfia
# Processing Record 50 of Set 12 | tomatlan
# Processing Record 1 of Set 13 | trapani
# Processing Record 2 of Set 13 | salcininkai
# Processing Record 3 of Set 13 | alamosa
# Processing Record 4 of Set 13 | ribeirao branco
# Processing Record 5 of Set 13 | batarci
# Processing Record 6 of Set 13 | la baule-escoublac
# Processing Record 7 of Set 13 | tabiauea
# City not found. Skipping...
# Processing Record 8 of Set 13 | yatou
# Processing Record 9 of Set 13 | meulaboh
# Processing Record 10 of Set 13 | fomboni
# Processing Record 11 of Set 13 | mahon
# Processing Record 12 of Set 13 | darhan
# Processing Record 13 of Set 13 | nhulunbuy
# Processing Record 14 of Set 13 | churapcha
# Processing Record 15 of Set 13 | caldwell
# Processing Record 16 of Set 13 | redmond
# Processing Record 17 of Set 13 | glace bay
# Processing Record 18 of Set 13 | coquimbo
# Processing Record 19 of Set 13 | darovskoy
# Processing Record 20 of Set 13 | port-cartier
# Processing Record 21 of Set 13 | boralday
# Processing Record 22 of Set 13 | henties bay
# Processing Record 23 of Set 13 | pesaro
# Processing Record 24 of Set 13 | aykhal
# Processing Record 25 of Set 13 | asau
# Processing Record 26 of Set 13 | vrangel
# Processing Record 27 of Set 13 | lubango
# Processing Record 28 of Set 13 | yomitan
# City not found. Skipping...
# Processing Record 29 of Set 13 | berlevag
# Processing Record 30 of Set 13 | ondorhaan
# City not found. Skipping...
# Processing Record 31 of Set 13 | kautokeino
# Processing Record 32 of Set 13 | jurmala
# Processing Record 33 of Set 13 | cotui
# Processing Record 34 of Set 13 | agadez
# Processing Record 35 of Set 13 | launceston
# Processing Record 36 of Set 13 | chlum u trebone
# Processing Record 37 of Set 13 | ouallam
# Processing Record 38 of Set 13 | satitoa
# City not found. Skipping...
# Processing Record 39 of Set 13 | yashan
# Processing Record 40 of Set 13 | falealupo
# City not found. Skipping...
# Processing Record 41 of Set 13 | mysliborz
# Processing Record 42 of Set 13 | tezu
# Processing Record 43 of Set 13 | bryant
# Processing Record 44 of Set 13 | heihe
# Processing Record 45 of Set 13 | kamenskoye
# City not found. Skipping...
# Processing Record 46 of Set 13 | irbeyskoye
# Processing Record 47 of Set 13 | batemans bay
# Processing Record 48 of Set 13 | hatillo
# Processing Record 49 of Set 13 | yima
# Processing Record 50 of Set 13 | deh rawud
# City not found. Skipping...
# Processing Record 1 of Set 14 | yangambi
# Processing Record 2 of Set 14 | xudat
# Processing Record 3 of Set 14 | flinders
# Processing Record 4 of Set 14 | cocoa beach
# Processing Record 5 of Set 14 | xai-xai
# Processing Record 6 of Set 14 | hanyang
# Processing Record 7 of Set 14 | loreto
# Processing Record 8 of Set 14 | meyungs
# City not found. Skipping...
# Processing Record 9 of Set 14 | dondo
# Processing Record 10 of Set 14 | iqaluit
# Processing Record 11 of Set 14 | coroata
# Processing Record 12 of Set 14 | dwarka
# Processing Record 13 of Set 14 | cumaribo
# City not found. Skipping...
# Processing Record 14 of Set 14 | kiruna
# Processing Record 15 of Set 14 | suoyarvi
# Processing Record 16 of Set 14 | hohhot
# Processing Record 17 of Set 14 | port augusta
# Processing Record 18 of Set 14 | kuryk
# Processing Record 19 of Set 14 | sterling
# Processing Record 20 of Set 14 | moree
# Processing Record 21 of Set 14 | waldoboro
# Processing Record 22 of Set 14 | parlakimidi
# Processing Record 23 of Set 14 | yuzhno-kurilsk
# Processing Record 24 of Set 14 | kampot
# Processing Record 25 of Set 14 | zyryanka
# Processing Record 26 of Set 14 | vostok
# Processing Record 27 of Set 14 | taraclia
# Processing Record 28 of Set 14 | yialos
# City not found. Skipping...
# Processing Record 29 of Set 14 | kinablangan
# Processing Record 30 of Set 14 | burica
# City not found. Skipping...
# Processing Record 31 of Set 14 | pousat
# City not found. Skipping...
# Processing Record 32 of Set 14 | elko
# Processing Record 33 of Set 14 | sangmelima
# Processing Record 34 of Set 14 | axim
# Processing Record 35 of Set 14 | copiapo
# Processing Record 36 of Set 14 | beipiao
# Processing Record 37 of Set 14 | asfi
# Processing Record 38 of Set 14 | port blair
# Processing Record 39 of Set 14 | pasni
# Processing Record 40 of Set 14 | yanan
# City not found. Skipping...
# Processing Record 41 of Set 14 | tadine
# Processing Record 42 of Set 14 | koulikoro
# Processing Record 43 of Set 14 | san rafael del sur
# Processing Record 44 of Set 14 | richards bay
# Processing Record 45 of Set 14 | jieshi
# Processing Record 46 of Set 14 | tias
# Processing Record 47 of Set 14 | shunyi
# Processing Record 48 of Set 14 | staryy nadym
# Processing Record 49 of Set 14 | bharatpur
# Processing Record 50 of Set 14 | catio
# Processing Record 1 of Set 15 | tarko-sale
# Processing Record 2 of Set 15 | kendari
# Processing Record 3 of Set 15 | snasa
# Processing Record 4 of Set 15 | pskov
# Processing Record 5 of Set 15 | kismayo
# Processing Record 6 of Set 15 | harnosand
# Processing Record 7 of Set 15 | lexington
# Processing Record 8 of Set 15 | ayia anna
# Processing Record 9 of Set 15 | havelock
# Processing Record 10 of Set 15 | masuda
# Processing Record 11 of Set 15 | kasempa
# Processing Record 12 of Set 15 | pimentel
# Processing Record 13 of Set 15 | leningradskiy
# Processing Record 14 of Set 15 | lata
# Processing Record 15 of Set 15 | altamont
# Processing Record 16 of Set 15 | bairiki
# Processing Record 17 of Set 15 | suao
# City not found. Skipping...
# Processing Record 18 of Set 15 | qaqortoq
# Processing Record 19 of Set 15 | nouna
# Processing Record 20 of Set 15 | terre-de-bas
# Processing Record 21 of Set 15 | mehamn
# Processing Record 22 of Set 15 | kalemie
# Processing Record 23 of Set 15 | porbandar
# Processing Record 24 of Set 15 | flin flon
# Processing Record 25 of Set 15 | svobodnyy
# Processing Record 26 of Set 15 | gizo
# Processing Record 27 of Set 15 | santa teresa
# Processing Record 28 of Set 15 | vigrestad
# Processing Record 29 of Set 15 | tambovka
# Processing Record 30 of Set 15 | ponta delgada
# Processing Record 31 of Set 15 | kamenka
# Processing Record 32 of Set 15 | okulovka
# Processing Record 33 of Set 15 | cobija
# Processing Record 34 of Set 15 | esso
# Processing Record 35 of Set 15 | broome
# Processing Record 36 of Set 15 | sur
# Processing Record 37 of Set 15 | nasirabad
# Processing Record 38 of Set 15 | kaka
# Processing Record 39 of Set 15 | peniche
# Processing Record 40 of Set 15 | tala
# Processing Record 41 of Set 15 | prince rupert
# Processing Record 42 of Set 15 | sirnach
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df
len(city_data)
# Out:
# 683

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)

# Reorder the column order
new_column_order = ["City", "Country", "Lat","Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

city_data_df = city_data_df[new_column_order]

city_data_df.tail()
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 678           Kaka      TM  37.3482   59.6143     25.27        21          23
# 679        Peniche      PT  39.3558   -9.3811     17.78        83           6
# 680           Tala      EG  30.6803   30.9429     22.59        25          34
# 681  Prince Rupert      CA  54.3161 -130.3201      4.00        75          90
# 682        Sirnach      CH  47.4622    8.9976     18.00        48          66
#
#      Wind Speed Current Description
# 678        8.76          few clouds
# 679        4.92           clear sky
# 680        7.93    scattered clouds
# 681        6.69     overcast clouds
# 682        0.51       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the weather_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
